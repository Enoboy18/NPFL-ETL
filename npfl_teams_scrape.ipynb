# %% [markdown]
# ### NPFL 2024/2025 Teams Scrape

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://en.wikipedia.org/wiki/2024%E2%80%9325_Nigeria_Premier_Football_League"

headers = {"User-Agent": "Mozilla/5.0"}  

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    2024–25 Nigeria Premier Football League - Wikipedia
#   </title>
#   <script>
# ...

# %%
import pandas as pd

URL = "https://en.wikipedia.org/wiki/2024%E2%80%9325_Nigeria_Premier_Football_League"

headers = {"User-Agent": "Mozilla/5.0"}
page = requests.get(URL, headers=headers)

soup = BeautifulSoup(page.content, "html.parser")

table = soup.find("table", class_="wikitable sortable")

if table:
    rows = []
    headers = []
  
    header_row = table.find("tr")
    for header in header_row.find_all("th"):
        headers.append(header.get_text(strip=True))
   
    for row in table.find_all("tr")[1:]: 
        row_data = []
        for cell in row.find_all(["td", "th"]):  
            row_data.append(cell.get_text(strip=True))
        if row_data:  
            rows.append(row_data)

    df = pd.DataFrame(rows, columns=headers)
    print(df)

else:
    print("Not found")
# Out:
#                   Team       Location Kit Supplier  \
# 0        Abia Warriors        Umuahia          Owu
# 1          Akwa United            Uyo          Owu
# 2       Bayelsa United        Yenagoa          GDF
# 3     Bendel Insurance     Benin City     Fourteen
# 4   El-Kanemi Warriors      Maiduguri
# 5        Enugu Rangers          Enugu   Cone Sport
# 6              Enyimba            Aba           KK
# 7            Heartland         Owerri            _
# 8         Ikorodu City  Ikorodu,Lagos
# 9         Kano Pillars           Kano         Play
# 10      Katsina United        Katsina          Owu
# 11        Kwara United         Ilorin          Owu
# 12          Lobi Stars        Makurdi          Owu
# 13     Nasarawa United          Lafia
# 14     Niger Tornadoes          Minna   Cone Sport
# 15      Plateau United            Jos      Kapspor
# 16          Remo Stars         Ikenne   Cone Sport
# 17       Rivers United  Port Harcourt          Owu
# ...

# %%
df
# Out:
#                   Team       Location Kit Supplier  \
# 0        Abia Warriors        Umuahia          Owu
# 1          Akwa United            Uyo          Owu
# 2       Bayelsa United        Yenagoa          GDF
# 3     Bendel Insurance     Benin City     Fourteen
# 4   El-Kanemi Warriors      Maiduguri
# 5        Enugu Rangers          Enugu   Cone Sport
# 6              Enyimba            Aba           KK
# 7            Heartland         Owerri            _
# 8         Ikorodu City  Ikorodu,Lagos
# 9         Kano Pillars           Kano         Play
# 10      Katsina United        Katsina          Owu
# 11        Kwara United         Ilorin          Owu
# 12          Lobi Stars        Makurdi          Owu
# 13     Nasarawa United          Lafia
# 14     Niger Tornadoes          Minna   Cone Sport
# 15      Plateau United            Jos      Kapspor
# 16          Remo Stars         Ikenne   Cone Sport
# 17       Rivers United  Port Harcourt          Owu
# ...

# %%
df.to_csv("Nigeria_Premier_League_2024_25.csv", index=False)
