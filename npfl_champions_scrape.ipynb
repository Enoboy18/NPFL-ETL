# %% [markdown]
# ### NPFL Champions by Season Scrape

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

URL = "https://en.wikipedia.org/wiki/Nigeria_Premier_Football_League#Champions_by_season"
headers = {"User-Agent": "Mozilla/5.0"}

page = requests.get(URL, headers=headers)
soup = BeautifulSoup(page.content, "html.parser")


tables = soup.find_all("table", class_="wikitable")


if len(tables) >= 3:
    table = tables[2]  
    rows = []
    headers = []

    
    header_row = table.find("tr")
    
    
    for header in header_row.find_all("th"):
        headers.append(header.get_text(strip=True))

    
    for row in table.find_all("tr")[1:]:  
        row_data = []
        
        for cell in row.find_all(["td", "th"]):
            row_data.append(cell.get_text(strip=True))

        
        if row_data:
            rows.append(row_data)

    if rows:
        df = pd.DataFrame(rows, columns=headers)
        print(df)
    else:
        print("No valid rows to display")
else:
    print("Table not found.")
# Out:
#    Année                              Champion
# 0   1972                        Mighty Jets(1)
# 1   1973                   Bendel Insurance(1)
# 2   1974         Rangers International F.C.(1)
# 3   1975         Rangers International F.C.(2)
# 4   1976                     Shooting Stars(1)
# 5   1977         Rangers International F.C.(3)
# 6   1978                       Racca Rovers(1)
# 7   1979                   Bendel Insurance(2)
# 8   1980                     Shooting Stars(2)
# 9   1981         Rangers International F.C.(4)
# 10  1982         Rangers International F.C.(5)
# 11  1983                     Shooting Stars(3)
# 12  1984         Rangers International F.C.(6)
# 13  1985                New Nigeria Bank FC(1)
# 14  1986                    Leventis United(1)
# 15  1987               Iwuanyanwu Nationale(1)
# 16  1988               Iwuanyanwu Nationale(2)
# 17  1989               Iwuanyanwu Nationale(3)
# 18  1990               Iwuanyanwu Nationale(4)
# ...

# %%
df
# Out:
#    Année                              Champion
# 0   1972                        Mighty Jets(1)
# 1   1973                   Bendel Insurance(1)
# 2   1974         Rangers International F.C.(1)
# 3   1975         Rangers International F.C.(2)
# 4   1976                     Shooting Stars(1)
# 5   1977         Rangers International F.C.(3)
# 6   1978                       Racca Rovers(1)
# 7   1979                   Bendel Insurance(2)
# 8   1980                     Shooting Stars(2)
# 9   1981         Rangers International F.C.(4)
# 10  1982         Rangers International F.C.(5)
# 11  1983                     Shooting Stars(3)
# 12  1984         Rangers International F.C.(6)
# 13  1985                New Nigeria Bank FC(1)
# 14  1986                    Leventis United(1)
# 15  1987               Iwuanyanwu Nationale(1)
# 16  1988               Iwuanyanwu Nationale(2)
# 17  1989               Iwuanyanwu Nationale(3)
# 18  1990               Iwuanyanwu Nationale(4)
# ...

# %%
df.to_csv("npfl_champions.csv", index=False)
print("File Saved")
# Out:
# File Saved

# %% [markdown]
# ### Scraping the Highest Goal Scorers

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://en.wikipedia.org/wiki/Nigeria_Premier_Football_League"
headers = {"User-Agent": "Mozilla/5.0"}

page = requests.get(URL, headers=headers)
soup = BeautifulSoup(page.content, "html.parser")

tables = soup.find_all("table")
for idx, table in enumerate(tables):
    print(f"Table {idx + 1}:")
    print(table.attrs) 
    print("\n")
# Out:
# Table 1:
# {'class': ['infobox'], 'style': 'width:auto; min-width:21em; max-width:25em'}
#
#
# Table 2:
# {'class': ['wikitable']}
#
#
# Table 3:
# {'class': ['wikitable']}
#
#
# Table 4:
# {'class': ['wikitable']}
#
#
# Table 5:
# {'class': ['wikitable']}
#
#
# Table 6:
# {'cellpadding': '3', 'cellspacing': '0', 'border': '1', 'style': 'margin:auto; background:#f7f8ff; font-size:95%; border:gray solid 1px; border-collapse:collapse;'}
#
#
# Table 7:
# {'class': ['nowraplinks', 'hlist', 'mw-collapsible', 'autocollapse', 'navbox-inner'], 'style': 'border-spacing:0;background:transparent;color:inherit'}
#
#
# Table 8:
# {'class': ['nowraplinks', 'navbox-subgroup'], 'style': 'border-spacing:0'}
#
#
# Table 9:
# {'class': ['nowraplinks', 'navbox-subgroup'], 'style': 'border-spacing:0'}
#
#
# Table 10:
# {'class': ['nowraplinks', 'navbox-subgroup'], 'style': 'border-spacing:0'}
#
#
# Table 11:
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

URL = "https://en.wikipedia.org/wiki/Nigeria_Premier_Football_League"
headers = {"User-Agent": "Mozilla/5.0"}

page = requests.get(URL, headers=headers)
soup = BeautifulSoup(page.content, "html.parser")

tables = soup.find_all("table")

if len(tables) >= 6:
    table = tables[5]
    rows = []
    headers = []

    header_row = table.find("tr")
    for header in header_row.find_all("th"):
        headers.append(header.get_text(strip=True))

    for row in table.find_all("tr")[1:]:  
        row_data = [cell.get_text(strip=True) for cell in row.find_all(["td", "th"])]
        if row_data:
            rows.append(row_data)

    if rows:
        df = pd.DataFrame(rows, columns=headers)
        print(df)
    else:
        print("No valid rows to display.")
else:
    print("Table not found.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
#    1020     )
#    1021 elif is_mi_list:
#    1022
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

URL = "https://en.wikipedia.org/wiki/Nigeria_Premier_Football_League"
headers = {"User-Agent": "Mozilla/5.0"}

page = requests.get(URL, headers=headers)
soup = BeautifulSoup(page.content, "html.parser")

tables = soup.find_all("table")

if len(tables) >= 6:
    table = tables[5]
    rows = []
    headers = []

    header_row = table.find("tr")
    for header in header_row.find_all("th"):
        headers.append(header.get_text(strip=True))

    print("Extracted Headers:", headers) 

    for row in table.find_all("tr")[1:]:  
        row_data = [cell.get_text(strip=True) for cell in row.find_all(["td", "th"])]
        print("Row data:", row_data) 
        if row_data:
            rows.append(row_data)

    if rows and all(len(row) == len(headers) for row in rows):
        df = pd.DataFrame(rows, columns=headers)
        print(df)
    else:
        print("Mismatch between header and row column counts.")
else:
    print("Table not found.")
# Out:
# Extracted Headers: []
# Row data: ['1990[24]', 'Ishaya Jatau', 'Iwuanyanwu Nationale', '17']
# Row data: ['1991', 'Richard Ojomo', 'Bendel United', '12']
# Row data: ['1992', 'Arthur Moses', 'Stationary Stores', '10']
# Row data: ['1993', 'Anthony Nwaigwe', 'Iwuanyanwu Nationale', '13']
# Row data: ['1994', 'Olumide Harris', 'Shooting Stars', '14']
# Row data: ['1995', 'Ben Agawam', 'Gombe United', '12']
# Row data: ['1996', 'Peter Anyiolobi', 'Enyimba', '9']
# Row data: ['1997', 'Paul Kpoughoul', 'Jasper United/BCC Lions', '16']
# Row data: ['1998', 'Hassan Minna', 'Gombe United', '14']
# Row data: ['1999', 'Emmanuel Ago', 'Iwuanyanwu Nationale', '14']
# Row data: ['2000', 'Peter Ijeh', 'Julius Berger', '14']
# Row data: ['2001', 'Uche Okereke', 'Rangers International F.C.', '13']
# Row data: ['2002', 'Joetex Frimpong / Victor Ezeji', 'El-Kanemi Warriors / Sharks of Ph', '16']
# Row data: ['2003', 'Chibuzor OzurumbaEndurance Idahor', 'Iwuanyanwu NationaleJulius Berger', '13']
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

URL = "https://en.wikipedia.org/wiki/Nigeria_Premier_Football_League"
headers = {"User-Agent": "Mozilla/5.0"}

page = requests.get(URL, headers=headers)
soup = BeautifulSoup(page.content, "html.parser")

tables = soup.find_all("table")

if len(tables) >= 6:
    table = tables[5]
    rows = []
    
    column_names = ["years", "scorers", "club", "goals"] 

    for row in table.find_all("tr")[1:]:
        row_data = [cell.get_text(strip=True) for cell in row.find_all("td")]
        if row_data:
            rows.append(row_data)
    if rows:
        df = pd.DataFrame(rows, columns=column_names)
        print(df)
    else:
        print("No valid rows to display.")
else:
    print("Table not found.")
# Out:
#         years                            scorers  \
# 0    1990[24]                       Ishaya Jatau
# 1        1991                      Richard Ojomo
# 2        1992                       Arthur Moses
# 3        1993                    Anthony Nwaigwe
# 4        1994                     Olumide Harris
# 5        1995                         Ben Agawam
# 6        1996                    Peter Anyiolobi
# 7        1997                     Paul Kpoughoul
# 8        1998                       Hassan Minna
# 9        1999                       Emmanuel Ago
# 10       2000                         Peter Ijeh
# 11       2001                       Uche Okereke
# 12       2002     Joetex Frimpong / Victor Ezeji
# 13       2003  Chibuzor OzurumbaEndurance Idahor
# 14       2004                      Kabiru Alausa
# 15       2005       Timothy AnjembeJoseph Akpala
# 16       2006                 Ikechukwu Ibenegbu
# 17       2007                         Aruwa Ameh
# ...

# %%
df
# Out:
#          year                            scorers  \
# 0    1990[24]                       Ishaya Jatau
# 1        1991                      Richard Ojomo
# 2        1992                       Arthur Moses
# 3        1993                    Anthony Nwaigwe
# 4        1994                     Olumide Harris
# 5        1995                         Ben Agawam
# 6        1996                    Peter Anyiolobi
# 7        1997                     Paul Kpoughoul
# 8        1998                       Hassan Minna
# 9        1999                       Emmanuel Ago
# 10       2000                         Peter Ijeh
# 11       2001                       Uche Okereke
# 12       2002     Joetex Frimpong / Victor Ezeji
# 13       2003  Chibuzor OzurumbaEndurance Idahor
# 14       2004                      Kabiru Alausa
# 15       2005       Timothy AnjembeJoseph Akpala
# 16       2006                 Ikechukwu Ibenegbu
# 17       2007                         Aruwa Ameh
# ...

# %%
import re
df['years'] = df['years'].apply(lambda x: re.sub(r'\[.*?\]', '', x))
df
# Out:
#         years                            scorers  \
# 0        1990                       Ishaya Jatau
# 1        1991                      Richard Ojomo
# 2        1992                       Arthur Moses
# 3        1993                    Anthony Nwaigwe
# 4        1994                     Olumide Harris
# 5        1995                         Ben Agawam
# 6        1996                    Peter Anyiolobi
# 7        1997                     Paul Kpoughoul
# 8        1998                       Hassan Minna
# 9        1999                       Emmanuel Ago
# 10       2000                         Peter Ijeh
# 11       2001                       Uche Okereke
# 12       2002     Joetex Frimpong / Victor Ezeji
# 13       2003  Chibuzor OzurumbaEndurance Idahor
# 14       2004                      Kabiru Alausa
# 15       2005       Timothy AnjembeJoseph Akpala
# 16       2006                 Ikechukwu Ibenegbu
# 17       2007                         Aruwa Ameh
# ...

# %%
df['years'] = df['years'].str.replace('"', '', regex=False)
df
# Out:
#       years                            scorers  \
# 0      1990                       Ishaya Jatau
# 1      1991                      Richard Ojomo
# 2      1992                       Arthur Moses
# 3      1993                    Anthony Nwaigwe
# 4      1994                     Olumide Harris
# 5      1995                         Ben Agawam
# 6      1996                    Peter Anyiolobi
# 7      1997                     Paul Kpoughoul
# 8      1998                       Hassan Minna
# 9      1999                       Emmanuel Ago
# 10     2000                         Peter Ijeh
# 11     2001                       Uche Okereke
# 12     2002     Joetex Frimpong / Victor Ezeji
# 13     2003  Chibuzor OzurumbaEndurance Idahor
# 14     2004                      Kabiru Alausa
# 15     2005       Timothy AnjembeJoseph Akpala
# 16     2006                 Ikechukwu Ibenegbu
# 17     2007                         Aruwa Ameh
# 18     2008                    Abubakar Babale
# ...

# %%
df['scorers'] = df['scorers'].str.replace(r'\[.*?\]', '', regex=True)
df
# Out:
#       years                            scorers  \
# 0      1990                       Ishaya Jatau
# 1      1991                      Richard Ojomo
# 2      1992                       Arthur Moses
# 3      1993                    Anthony Nwaigwe
# 4      1994                     Olumide Harris
# 5      1995                         Ben Agawam
# 6      1996                    Peter Anyiolobi
# 7      1997                     Paul Kpoughoul
# 8      1998                       Hassan Minna
# 9      1999                       Emmanuel Ago
# 10     2000                         Peter Ijeh
# 11     2001                       Uche Okereke
# 12     2002     Joetex Frimpong / Victor Ezeji
# 13     2003  Chibuzor OzurumbaEndurance Idahor
# 14     2004                      Kabiru Alausa
# 15     2005       Timothy AnjembeJoseph Akpala
# 16     2006                 Ikechukwu Ibenegbu
# 17     2007                         Aruwa Ameh
# 18     2008                    Abubakar Babale
# ...

# %%
df.to_csv("topscorers.csv", index=False)
print("File Saved")
# Out:
# File Saved

# %% [markdown]
# ##### Excel was used for the final data cleaning
